# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import libraries
import csv
import torch
import pandas as pd

# %%
# set data path
Data_path = "/content/drive/MyDrive/Colab Notebooks/LinkedIn Learning/01_Hands-On PyTorch Machine Learning Explore the capabilities of PyTorch/Tutors.csv"

# %%
# read the top 50 rows of the csv file into a pandas dataframe
# install Pandas library: pip3 install pandas
df = pd.read_csv(Data_path,nrows=50)

# %%
# display the pandas dataframe
display(df)
# Out:
#    username                name  gender            Address  stateZip  \
# 0     user1            John Doe    Male        123 Main St  CA 90001
# 1     user2          Jane Smith  Female         456 Oak St  NY 10001
# 2     user3     Michael Johnson    Male       789 Maple St  TX 77001
# 3     user4         Emily Brown  Female         135 Elm St  IL 60601
# 4     user5  Christopher Wilson    Male        246 Pine St  PA 19101
# 5     user6   Elizabeth Johnson  Female       369 Cedar St  GA 30301
# 6     user7      James Anderson    Male       482 Birch St  FL 33101
# 7     user8     Patricia Taylor  Female      159 Cherry St  NC 28201
# 8     user9       Robert Thomas    Male     891 Redwood St  OH 44101
# 9    user10    Jennifer Jackson  Female         111 Ash St  MI 48201
# 10   user11    William Martinez    Male    234 Magnolia St  VA 23201
# 11   user12        Linda Harris  Female     357 Dogwood St  MA 02101
# 12   user13       Richard Smith    Male       369 Holly St  WA 98101
# 13   user14         Barbara Lee  Female      123 Spruce St  CO 80201
# 14   user15       Joseph Walker    Male       456 Apple St  AZ 85001
# 15   user16          Susan Hall  Female      789 Orange St  NJ 07101
# 16   user17       Charles Brown    Male         135 Fig St  IN 46201
# 17   user18          Mary Davis  Female       246 Olive St  TN 37201
# 18   user19      Thomas Jackson    Male        369 Pear St  MO 64101
# 19   user20      Karen Thompson  Female       482 Peach St  MD 21201
# 20   user21         David White    Male      159 Almond St  WI 53201
# 21   user22        Carol Garcia  Female      891 Cherry St  AL 36101
# 22   user23    Daniel Rodriguez    Male        111 Plum St  SC 29201
# 23   user24        Sharon Young  Female   234 Persimmon St  LA 70101
# 24   user25      Paul Hernandez    Male     357 Apricot St  KY 40201
# 25   user26          Diane Hall  Female       369 Grape St  OR 97201
# 26   user27            Mark Lee    Male  482 Blackberry St  OK 73101
# 27   user28         Nancy Perez  Female   159 Raspberry St  CT 06101
# 28   user29        Donald Lewis    Male  891 Strawberry St  IA 50301
# 29   user30   Michelle Robinson  Female   111 Blueberry St  MS 39201
# 30   user31        George Clark    Male     234 Currant St  AR 72201
# 31   user32        Laura Nelson  Female      357 Raisin St  KS 67201
# 32   user33    Kenneth Mitchell    Male   369 Cranberry St  UT 84101
# 33   user34      Rebecca Carter  Female         482 Fig St  NV 89101
# 34   user35    Stephen Phillips    Male   159 Nectarine St  NE 68101
# 35   user36      Kathleen Evans  Female   891 Tangerine St  NM 87101
# 36   user37       Edward Turner    Male    111 Mandarin St  ME 04101
# 37   user38       Judith Torres  Female  234 Clementine St  RI 02901
# 38   user39        Brian Murphy    Male  357 Grapefruit St  ID 83701
# 39   user40     Deborah Collins  Female        369 Lime St  NH 03101
# 40   user41      Ronald Jenkins    Male       482 Lemon St  SD 57101
# 41   user42      Dorothy Bailey  Female       159 Melon St  ND 58101
# 42   user43        Larry Rivera    Male  891 Cantaloupe St  MT 59101
# 43   user44      Shirley Cooper  Female  111 Watermelon St  DE 19901
# 44   user45        Kevin Watson    Male    234 Honeydew St  VT 05401
# 45   user46       Pamela Foster  Female        357 Kiwi St  AK 99501
# 46   user47        Raymond Gray    Male       369 Mango St  HI 96801
# 47   user48       Gloria Bryant  Female      482 Papaya St  WV 25301
# 48   user49         Alan Powell    Male       159 Grape St  WY 82001
# 49   user50        Lisa Simmons  Female   891 Pineapple St  DC 20001
#
#                            email  sessions
# 0            johndoe@example.com         3
# 1          janesmith@example.com         7
# 2           michaelj@example.com        10
# 3         emilybrown@example.com         4
# 4        chriswilson@example.com         2
# 5         lizjohnson@example.com         9
# 6      jamesanderson@example.com         5
# 7     patriciataylor@example.com         1
# 8       robertthomas@example.com         8
# 9    jenniferjackson@example.com         6
# 10   williammartinez@example.com         3
# 11       lindaharris@example.com         4
# 12      richardsmith@example.com         7
# 13        barbaralee@example.com         2
# 14      josephwalker@example.com         6
# 15         susanhall@example.com         9
# 16      charlesbrown@example.com         1
# 17         marydavis@example.com         5
# 18     thomasjackson@example.com         8
# 19     karenthompson@example.com        10
# 20        davidwhite@example.com         3
# 21       carolgarcia@example.com         7
# 22   danielrodriguez@example.com         4
# 23       sharonyoung@example.com         6
# 24     paulhernandez@example.com         2
# 25         dianehall@example.com         9
# 26           marklee@example.com         5
# 27        nancyperez@example.com         1
# 28       donaldlewis@example.com         8
# 29  michellerobinson@example.com        10
# 30       georgeclark@example.com         3
# 31       lauranelson@example.com         4
# 32   kennethmitchell@example.com         7
# 33     rebeccacarter@example.com         2
# 34   stephenphillips@example.com         6
# 35     kathleenevans@example.com         9
# 36      edwardturner@example.com         1
# 37      judithtorres@example.com         5
# 38       brianmurphy@example.com         8
# 39    deborahcollins@example.com        10
# 40     ronaldjenkins@example.com         3
# 41     dorothybailey@example.com         7
# 42       larryrivera@example.com         4
# 43     shirleycooper@example.com         6
# 44       kevinwatson@example.com         2
# 45      pamelafoster@example.com         9
# 46       raymondgray@example.com         5
# 47      gloriabryant@example.com         1
# 48        alanpowell@example.com         8
# 49       lisasimmons@example.com        10

# %%
import torch.utils.data as data_utils
pd.to_numeric(df["sessions"])
sessions_df = pd.DataFrame(df['sessions'])

# creating tensor from session_df
train_tensor = torch.tensor(sessions_df['sessions'].values)

# printing out result
print(train_tensor)
# Out:
# tensor([ 3,  7, 10,  4,  2,  9,  5,  1,  8,  6,  3,  4,  7,  2,  6,  9,  1,  5,
#          8, 10,  3,  7,  4,  6,  2,  9,  5,  1,  8, 10,  3,  4,  7,  2,  6,  9,
#          1,  5,  8, 10,  3,  7,  4,  6,  2,  9,  5,  1,  8, 10])

# %%
# train_loader = data_utils.DataLoader(train_tensor, batch_size=10, shuffle=True)
