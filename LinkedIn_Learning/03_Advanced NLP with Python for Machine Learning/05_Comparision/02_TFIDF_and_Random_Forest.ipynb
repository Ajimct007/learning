# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LinkedIn Learning/03_Advanced NLP with Python for Machine Learning/Ex_Files_Adv_NLP_Python_ML/Exercise Files/data/X_train.csv')
X_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LinkedIn Learning/03_Advanced NLP with Python for Machine Learning/Ex_Files_Adv_NLP_Python_ML/Exercise Files/data/X_test.csv')
y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LinkedIn Learning/03_Advanced NLP with Python for Machine Learning/Ex_Files_Adv_NLP_Python_ML/Exercise Files/data/y_train.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LinkedIn Learning/03_Advanced NLP with Python for Machine Learning/Ex_Files_Adv_NLP_Python_ML/Exercise Files/data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['let', 'know', 'details', 'fri', 'u', 'find',...
# 1  ['private', '2003', 'account', 'statement', 's...
# 2  ['enjoy', 'showers', 'possessiveness', 'poured...
# 3  ['beautiful', 'truth', 'gravity', 'read', 'car...
# 4                    ['onum', 'ela', 'pa', 'normal']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'let': 4335,
#  'know': 4201,
#  'details': 2419,
#  'fri': 3155,
#  'find': 3008,
#  'cos': 2137,
#  'im': 3818,
#  'tom': 7361,
#  'mentionned': 4716,
#  'chinese': 1905,
#  'thanks': 7202,
#  'private': 5752,
#  '2003': 390,
#  'account': 853,
#  'statement': 6834,
#  'shows': 6487,
#  '800': 706,
#  'unredeemed': 7591,
#  'points': 5618,
#  'call': 1689,
#  '08718738002': 149,
#  'identifier': 3796,
#  'code': 1992,
#  '48922': 572,
#  'expires': 2867,
#  '211104': 401,
#  'enjoy': 2747,
#  'showers': 6483,
#  'possessiveness': 5659,
#  'poured': 5676,
#  'ur': 7615,
#  'loved': 4487,
#  'ones': 5272,
#  'bcoz': 1345,
#  'world': 8011,
#  'lies': 4351,
#  'golden': 3345,
#  'gift': 3293,
#  'truly': 7469,
#  'beautiful': 1354,
#  'truth': 7472,
#  'gravity': 3404,
#  'read': 5936,
#  'carefully': 1755,
#  'heart': 3554,
#  'feels': 2962,
#  'light': 4363,
#  'someone': 6663,
#  'heavy': 3562,
#  'leaves': 4309,
#  'goodmorning': 3362,
#  'onum': 5282,
#  'ela': 2705,
#  'pa': 5373,
#  'normal': 5123,
#  'wake': 7766,
#  'gt': 3438,
#  'saying': 6282,
#  'havent': 3532,
#  'explicitly': 2870,
#  'told': 7357,
#  'nora': 5119,
#  'probably': 5762,
#  'gonna': 3352,
#  'bother': 1527,
#  'yeah': 8147,
#  'sure': 7014,
#  'give': 3306,
#  'couple': 2157,
#  'minutes': 4783,
#  'track': 7419,
#  'wallet': 7777,
#  'like': 4367,
#  'goes': 3336,
#  'friends': 3161,
#  'imma': 3825,
#  'flip': 3052,
#  'shit': 6444,
#  'half': 3482,
#  'hour': 3708,
#  'lol': 4444,
#  'yes': 8159,
#  'friendship': 3163,
#  'hanging': 3502,
#  'thread': 7274,
#  'cause': 1788,
#  'wont': 7990,
#  'buy': 1660,
#  'stuff': 6931,
#  'outside': 5350,
#  'hours': 3710,
#  'called': 1704,
#  'whole': 7907,
#  'family': 2917,
#  'started': 6827,
#  '2004': 391,
#  '0784987': 37,
#  '786': 693,
#  'bonus': 1505,
#  'claim': 1937,
#  '08719180219': 151,
#  '45239': 567,
#  '060505': 18,
#  'convey': 2111,
#  'regards': 6006,
#  'single': 6533,
#  'line': 4381,
#  'big': 1422,
#  'meaning': 4671,
#  'miss': 4791,
#  'anything': 1076,
#  'best': 1402,
#  'life': 4352,
#  'gloucesterroad': 3318,
#  'uup': 7652,
#  'later': 4277,
#  'ok': 5243,
#  'least': 4305,
#  'armands': 1135,
#  'still': 6862,
#  'around': 1141,
#  '22': 406,
#  'days': 2314,
#  'kick': 4153,
#  'euro2004': 2796,
#  'kept': 4140,
#  'date': 2299,
#  'latest': 4279,
#  'news': 5043,
#  'results': 6104,
#  'daily': 2270,
#  'removed': 6042,
#  'send': 6359,
#  'get': 3279,
#  'txt': 7515,
#  'stop': 6875,
#  '83222': 734,
#  'hello': 3572,
#  'love': 4485,
#  'went': 7870,
#  'day': 2311,
#  'alright': 1005,
#  'think': 7253,
#  'sweet': 7040,
#  'jolt': 4067,
#  'remind': 6035,
#  'hear': 3550,
#  'screamed': 6309,
#  'across': 862,
#  'sea': 6317,
#  'ahmad': 947,
#  'al': 968,
#  'hallaq': 3486,
#  'owned': 5365,
#  'possessive': 5658,
#  'passionate': 5435,
#  'kiss': 4174,
#  'cthen': 2216,
#  'thk': 7262,
#  'shd': 6422,
#  'enuff': 2765,
#  'got': 3376,
#  'conclusion': 2067,
#  'contents': 2103,
#  'pg': 5510,
#  'references': 5994,
#  'ill': 3815,
#  'da': 2258,
#  'cover': 2164,
#  'secret': 6325,
#  'admirer': 890,
#  'looking': 4458,
#  'make': 4589,
#  'contact': 2096,
#  'ufind': 7534,
#  'rreveal': 6190,
#  'thinks': 7257,
#  'specialcall': 6734,
#  '09058094594': 180,
#  'chance': 1824,
#  'search': 6318,
#  'hard': 3514,
#  'itlet': 3971,
#  'try': 7474,
#  'die': 2449,
#  'toot': 7388,
#  'fringe': 3166,
#  'want': 7788,
#  'lick': 4347,
#  'pussy': 5845,
#  'thats': 7217,
#  'good': 3354,
#  'lets': 4336,
#  'thank': 7201,
#  'god': 3331,
#  'please': 5583,
#  'complete': 2047,
#  'drug': 2615,
#  'lots': 4474,
#  'water': 7810,
#  'used': 7633,
#  'hope': 3684,
#  'agents': 934,
#  'dont': 2554,
#  'drop': 2610,
#  'since': 6527,
#  'ive': 3984,
#  'booked': 1509,
#  'things': 7252,
#  'year': 8149,
#  'boston': 1525,
#  'nyc': 5188,
#  'experiment': 2863,
#  'dear': 2331,
#  'omw': 5267,
#  'back': 1271,
#  'tampa': 7098,
#  'west': 7877,
#  'palm': 5392,
#  'happened': 3506,
#  'plus': 5595,
#  'hows': 3719,
#  'mode': 4835,
#  'weekend': 7848,
#  'bored': 1520,
#  'housewives': 3714,
#  'chat': 1847,
#  '08717507711': 130,
#  'btnational': 1620,
#  'rate': 5912,
#  '10pmin': 272,
#  'landlines': 4255,
#  'watching': 7808,
#  'movie': 4894,
#  'already': 1003,
#  'xy': 8132,
#  'wants': 7792,
#  'shop': 6458,
#  'shopping': 6460,
#  'didnt': 2445,
#  'holla': 3661,
#  'haf': 3472,
#  'eaten': 2667,
#  'wat': 7805,
#  'time': 7304,
#  'wan': 7783,
#  'come': 2019,
#  'mobile': 4826,
#  '11': 275,
#  'months': 4866,
#  'entitled': 2760,
#  'update': 7602,
#  'colour': 2012,
#  'mobiles': 4827,
#  'camera': 1721,
#  'free': 3135,
#  'co': 1982,
#  '08002986030': 51,
#  'evo': 2827,
#  'download': 2573,
#  'flash': 3042,
#  'jealous': 4025,
#  'meanwhile': 4676,
#  'suite': 6976,
#  'xavier': 8112,
#  'decided': 2347,
#  'us': 7628,
#  'ltgt': 4515,
#  'seconds': 6324,
#  'warning': 7798,
#  'samantha': 6245,
#  'coming': 2027,
#  'playing': 5580,
#  'jays': 4019,
#  'guitar': 3455,
#  'impress': 3834,
#  'also': 1008,
#  'doug': 2571,
#  'realizes': 5948,
#  'live': 4411,
#  'anymore': 1070,
#  'messages': 4734,
#  'without': 7959,
#  'recharge': 5972,
#  'hi': 3609,
#  'housemaid': 3713,
#  'murderer': 4944,
#  'coz': 2167,
#  'man': 4598,
#  'murdered': 4943,
#  'th': 7197,
#  'january': 4010,
#  'public': 5824,
#  'holiday': 3659,
#  'govtinstituitions': 3383,
#  'closedincluding': 1966,
#  'post': 5662,
#  'officeunderstand': 5226,
#  'yo': 8179,
#  'sorry': 6697,
#  'shower': 6481,
#  'sup': 6997,
#  'txting': 7520,
#  'driving': 2606,
#  'dizzamn': 2512,
#  'aight': 955,
#  'ask': 1166,
#  'suitemates': 6977,
#  'thanx': 7207,
#  'lot': 4472,
#  'help': 3578,
#  'hey': 3604,
#  'name': 4970,
#  'gautham': 3244,
#  'ah': 942,
#  'promise': 5791,
#  'take': 7082,
#  'care': 1751,
#  'princess': 5743,
#  'run': 6211,
#  'pics': 5536,
#  'ttyl': 7488,
#  'home': 3665,
#  'guess': 3448,
#  'min': 4764,
#  'xmas': 8117,
#  'radio': 5882,
#  'times': 7306,
#  'forgot': 3104,
#  'eh': 2698,
#  'bring': 1590,
#  'babe': 1262,
#  'ya': 8134,
#  'tel': 7146,
#  'wats': 7816,
#  'problem': 5763,
#  'total': 7406,
#  'disappointment': 2487,
#  'texted': 7189,
#  'craziest': 2182,
#  'fear': 2951,
#  'fainting': 2902,
#  'housework': 3715,
#  'quick': 5865,
#  'cuppa': 2234,
#  'go': 3323,
#  'fool': 3086,
#  'cheat': 1854,
#  'others': 5332,
#  'knowhe': 4202,
#  'film': 3000,
#  'computer': 2057,
#  'aah': 816,
#  'cuddle': 2223,
#  'would': 8031,
#  'lush': 4533,
#  'id': 3790,
#  'need': 5010,
#  'tea': 7127,
#  'soup': 6714,
#  'kind': 4167,
#  'fumbling': 3197,
#  'wrong': 8049,
#  'phone': 5520,
#  'answer': 1058,
#  'one': 5271,
#  'assume': 1178,
#  'people': 5474,
#  'well': 7862,
#  'everything': 2820,
#  'dehydrated': 2369,
#  'worried': 8016,
#  'must': 4948,
#  'theres': 7239,
#  'way': 7819,
#  'body': 1497,
#  'repairs': 6052,
#  'quite': 5869,
#  'shouldnt': 6475,
#  'worry': 8019,
#  'slow': 6597,
#  'first': 3027,
#  'tests': 7180,
#  'guide': 3452,
#  'ovulation': 5361,
#  'relax': 6018,
#  'nothing': 5134,
#  'youve': 8204,
#  'said': 6232,
#  'reason': 5953,
#  'keep': 4133,
#  'followin': 3079,
#  'girls': 3303,
#  'office': 5223,
#  'may': 4662,
#  'wonder': 7986,
#  'smiling': 6618,
#  'sore': 6694,
#  'hopeing': 3688,
#  'pissed': 5555,
#  'remember': 6029,
#  'gone': 3349,
#  'sisters': 6544,
#  'something': 6669,
#  'okay': 5244,
#  'including': 3846,
#  'bugis': 1632,
#  'sale': 6237,
#  'arsenal': 1149,
#  'dartboard': 2295,
#  'condition': 2068,
#  'doubles': 2568,
#  'trebles': 7451,
#  'nope': 5118,
#  'show': 6479,
#  'next': 5048,
#  'week': 7846,
#  'nonenowhere': 5113,
#  'ikno': 3811,
#  'doesdiscountshitinnit': 2529,
#  'shes': 6429,
#  'drinkin': 2599,
#  'friday': 3156,
#  'leave': 4308,
#  'pongaldo': 5636,
#  'work': 8003,
#  'place': 5560,
#  'really': 5949,
#  'crashed': 2179,
#  'cuddled': 2224,
#  'sofa': 6650,
#  'excited': 2841,
#  'spend': 6747,
#  'happy': 3513,
#  'wanna': 7786,
#  'gym': 3463,
#  'watch': 7806,
#  'lor': 4465,
#  'saw': 6278,
#  'swatch': 7035,
#  'ard': 1119,
#  '116': 280,
#  '2nd': 459,
#  'opinion': 5296,
#  'leh': 4319,
#  'ìï': 8230,
#  'bot': 1526,
#  'notes': 5132,
#  'oredi': 5317,
#  'juz': 4100,
#  'rem': 6025,
#  'youll': 8195,
#  'near': 5000,
#  'campus': 1724,
#  'splashmobile': 6762,
#  'choose': 1915,
#  '1000s': 262,
#  'gr8': 3386,
#  'tones': 7371,
#  'wk': 7965,
#  'subscrition': 6956,
#  'service': 6383,
#  'weekly': 7850,
#  'costing': 2141,
#  '300p': 487,
#  'credit': 2190,
#  'neshanthtel': 5025,
#  'took': 7383,
#  'long': 4450,
#  'roommates': 6173,
#  'forever': 3097,
#  'multiply': 4931,
#  'numbers': 5175,
#  'independently': 3858,
#  'count': 2151,
#  'decimal': 2349,
#  'division': 2509,
#  'push': 5842,
#  'places': 5563,
#  'showed': 6480,
#  'worries': 8018,
#  'noi': 5098,
#  'rumour': 6210,
#  'going': 3341,
#  'apartment': 1083,
#  'chennai': 1873,
#  'moan': 4823,
#  'thin': 7250,
#  'faultal': 2942,
#  'de': 2321,
#  'arguments': 1129,
#  'faultfed': 2943,
#  'himso': 3621,
#  'hav': 3530,
#  '2go': 446,
#  'thanxxx': 7209,
#  'yup': 8215,
#  'printing': 5747,
#  'handing': 3493,
#  'sent': 6370,
#  'scream': 6308,
#  'bed': 1362,
#  'noon': 5115,
#  'see': 6334,
#  'whats': 7888,
#  'erutupalam': 2778,
#  'thandiyachu': 7198,
#  'new': 5038,
#  'theory': 7233,
#  'argument': 1128,
#  'wins': 7942,
#  'situation': 6551,
#  'loses': 4468,
#  'person': 5495,
#  'argue': 1127,
#  'amp': 1025,
#  'say': 6279,
#  'always': 1013,
#  'correct': 2131,
#  'thought': 7271,
#  'thing': 7251,
#  'get4an18th': 3280,
#  'loves': 4495,
#  'much': 4923,
#  'dude': 2631,
#  'buff': 1629,
#  'wind': 7931,
#  'change': 1826,
#  'sentence': 6372,
#  'concentrate': 2061,
#  'educational': 2681,
#  'career': 1753,
#  'leaving': 4310,
#  'remains': 6027,
#  'bro': 1597,
#  'amongst': 1022,
#  'bros': 1603,
#  'win': 7929,
#  'newest': 5040,
#  'åòharry': 8227,
#  'potter': 5672,
#  'order': 5314,
#  'phoenix': 5519,
#  'book': 1508,
#  'reply': 6061,
#  'harry': 3521,
#  'questions': 5863,
#  'among': 1021,
#  'readers': 5937,
#  'receive': 5964,
#  'msg': 4905,
#  'wasnt': 7801,
#  'swollen': 7052,
#  'glands': 3312,
#  'throat': 7279,
#  'end': 2732,
#  'whatsup': 7889,
#  'sleep': 6578,
#  'urgent': 7618,
#  '09061213237': 190,
#  'landline': 4253,
#  '5000': 602,
#  'cash': 1774,
#  'await': 1239,
#  'collection': 2008,
#  'cs': 2211,
#  'sae': 6226,
#  'po': 5599,
#  'box': 1538,
#  '177': 349,
#  'm227xy': 4545,
#  '16': 345,
#  'hr': 3725,
#  'posting': 5668,
#  'chennaibecause': 1874,
#  'working': 8007,
#  'cant': 1736,
#  'never': 5035,
#  'intention': 3908,
#  'rather': 5915,
#  'room': 6170,
#  'clean': 1949,
#  'visitors': 7719,
#  'maybe': 4664,
#  'choice': 1913,
#  'wanted': 7790,
#  'embarassed': 2721,
#  'youd': 8188,
#  'feel': 2958,
#  'friend': 3160,
#  'morning': 4875,
#  'tried': 7456,
#  'else': 2716,
#  'fishrman': 3030,
#  'woke': 7980,
#  'early': 2653,
#  'mrng': 4901,
#  'dark': 2286,
#  'waited': 7761,
#  'found': 3119,
#  'sack': 6222,
#  'ful': 3193,
#  'stones': 6873,
#  'strtd': 6917,
#  'throwin': 7281,
#  'thm': 7263,
#  'in2': 3840,
#  'pass': 5431,
#  'atlast': 1191,
#  'jus': 4096,
#  '1stone': 378,
#  'sun': 6987,
#  'rose': 6176,
#  'tht': 7287,
#  'nt': 5163,
#  'diamonds': 2438,
#  'moraldont': 4871,
#  'night': 5060,
#  'project': 5786,
#  'frens': 3150,
#  'ofcourse': 5215,
#  'upload': 7606,
#  'songs': 6682,
#  'enufcredeit': 2764,
#  'tocallshall': 7342,
#  'ileave': 3814,
#  'uni': 7575,
#  'bus': 1650,
#  'yor': 8183,
#  'house': 3711,
#  'course': 2160,
#  'gods': 3333,
#  'hold': 3655,
#  'right': 6130,
#  'today': 7344,
#  'song': 6681,
#  'dedicated': 2355,
#  'dedicate': 2354,
#  'valuable': 7661,
#  'frnds': 3169,
#  'rply': 6188,
#  'okie': 5249,
#  'ooooooh': 5286,
#  'tell': 7150,
#  'yoville': 8205,
#  'reaching': 5933,
#  'message': 4728,
#  '8007': 708,
#  '25p': 421,
#  'alfie': 980,
#  'moons': 4869,
#  'children': 1899,
#  'mob': 4824,
#  'm8s': 4551,
#  'tone': 7370,
#  'charity': 1838,
#  'nokias': 5108,
#  'poly': 5626,
#  'polys': 5633,
#  'zed': 8220,
#  '08701417012': 71,
#  'profit': 5782,
#  'ha': 3467,
#  'either': 2703,
#  'clever': 1956,
#  'simple': 6522,
#  'pears': 5464,
#  'perfect': 5480,
#  'christmas': 1924,
#  'baaaaabe': 1261,
#  'misss': 4797,
#  'youuuuu': 8203,
#  'teach': 7128,
#  'class': 1944,
#  'trying': 7476,
#  'todays': 7347,
#  'draw': 2586,
#  '2000': 388,
#  'prize': 5755,
#  'guaranteed': 3441,
#  '09066358361': 226,
#  'land': 4251,
#  'y87': 8133,
#  'valid': 7659,
#  '12hrs': 296,
#  '86688': 758,
#  '150pmsg': 323,
#  'rcvd': 5927,
#  'hgsuite3422landsroww1j6hl': 3608,
#  'ldn': 4293,
#  '18': 350,
#  'years': 8150,
#  'salt': 6242,
#  'rub': 6199,
#  'open': 5288,
#  'wounds': 8034,
#  'awww': 1248,
#  'dat': 2298,
#  'nice': 5053,
#  'tonight': 7378,
#  'lonely': 4449,
#  'xxx': 8125,
#  'nokia': 5104,
#  '7250i': 682,
#  'auction': 1205,
#  'part': 5421,
#  '86021': 754,
#  'hgsuite3422lands': 3607,
#  'roww1jhl': 6184,
#  'complimentary': 2052,
#  'star': 6821,
#  'ibiza': 3780,
#  '10000': 259,
#  'needs': 5015,
#  '09066364349': 232,
#  'lose': 4467,
#  'box434sk38wp150ppm18': 1549,
#  'sno': 6639,
#  'competition': 2041,
#  'nah': 4965,
#  'perpetual': 5492,
#  'dd': 2320,
#  'panasonic': 5395,
#  'bluetoothhdset': 1488,
#  'motorola': 4887,
#  'doublemins': 2567,
#  'doubletxt': 2569,
#  'orange': 5311,
#  'contract': 2106,
#  'mobileupd8': 4830,
#  '08000839402': 46,
#  '2optout': 464,
#  'seeking': 6337,
#  'lady': 4242,
#  'street': 6899,
#  'freak': 3131,
#  'sheets': 6424,
#  'shaking': 6410,
#  'booty': 1517,
#  'dance': 2277,
#  'floor': 3057,
#  'sim': 6520,
#  '08715203685': 122,
#  'code4xx26': 1993,
#  '131004': 300,
#  'pick': 5532,
#  'carso': 1770,
#  'bit': 1443,
#  'smile': 6614,
#  'hppnss': 3724,
#  'tear': 7135,
#  'sorrow': 6695,
#  'mine': 4770,
#  'wil': 7923,
#  'forevr': 3098,
#  'goodfriend': 3359,
#  'cool': 2120,
#  'hell': 3570,
#  'lemme': 4323,
#  'youre': 8198,
#  'smoking': 6624,
#  'use': 7632,
#  'wylie': 8107,
#  'smokes': 6623,
#  'justify': 4098,
#  'ruining': 6204,
#  'fuck': 3184,
#  'rhode': 6124,
#  'island': 3957,
#  'wherever': 7898,
#  'alone': 1000,
#  'bong': 1504,
#  'car': 1746,
#  'cud': 2222,
#  'ppl': 5682,
#  'gona': 3348,
#  'l8': 4228,
#  'buses': 1651,
#  'gon': 3347,
#  'past': 5439,
#  'full': 3195,
#  'waitin': 7762,
#  'pete': 5505,
#  'innocent': 3887,
#  'fun': 3198,
#  'oh': 5236,
#  'many': 4613,
#  'responsibilities': 6092,
#  'haha': 3473,
#  'officially': 5229,
#  'paid': 5384,
#  'market': 4622,
#  '8th': 793,
#  'boytoy': 1557,
#  'geeee': 3260,
#  'wish': 7948,
#  'cuddling': 2225,
#  'enjoyed': 2748,
#  'content': 2100,
#  'text': 7184,
#  '61610': 641,
#  'unsubscribe': 7596,
#  'help08712400602450p': 3581,
#  'provided': 5810,
#  'tones2youcouk': 7373,
#  'captain': 1744,
#  'kanoil': 4119,
#  'wen': 7867,
#  'depends': 2396,
#  'persons': 5500,
#  'story': 6891,
#  'great': 3409,
#  'guild': 3453,
#  'could': 2147,
#  'meet': 4687,
#  'bristol': 1594,
#  'road': 6150,
#  'somewhere': 6675,
#  'touch': 7409,
#  'plans': 5571,
#  'flight': 3049,
#  'yesbut': 8163,
#  'received': 5966,
#  'understood': 7565,
#  'acted': 865,
#  'upon': 7607,
#  'dats': 2305,
#  'straight': 6894,
#  'dogg': 2534,
#  'slowly': 6600,
#  'godi': 3332,
#  'youclean': 8187,
#  'bloodsend': 1478,
#  'ten': 7161,
#  'special': 6733,
#  'miracle': 4785,
#  'tomorrow': 7367,
#  'itplspls': 3975,
#  'number': 5172,
#  'awarded': 1243,
#  'caller': 1705,
#  '09058095201': 183,
#  'ringtonefrom': 6139,
#  'httptms': 3734,
#  'widelivecomindex': 7914,
#  'wmlid1b6a5ecef91ff937819firsttrue180430jul05': 7974,
#  'wondarfull': 7985,
#  'kkim': 4187,
#  'tirunelvali': 7319,
#  'uncle': 7554,
#  'amount': 1024,
#  'taking': 7088,
#  'dress': 2595,
#  'moneyi': 4855,
#  'feb': 2954,
#  'lit': 4407,
#  'hair': 3478,
#  'fire': 3021,
#  'trip': 7457,
#  'decide': 2346,
#  'easter': 2664,
#  'ayo': 1252,
#  'travelled': 7443,
#  'forgotten': 3105,
#  'guy': 3458,
#  'tescos': 7176,
#  'speak': 6731,
#  'soon': 6687,
#  'reminder': 6037,
#  'o2': 5196,
#  '250': 417,
#  'pounds': 5675,
#  'offers': 5221,
#  'pls': 5591,
#  'postcode': 5665,
#  'relieved': 6022,
#  'westonzoyland': 7880,
#  'plan': 5564,
#  'yunny': 8212,
#  'walking': 7774,
#  'citylink': 1935,
#  'faster': 2932,
#  'hungry': 3756,
#  'rude': 6200,
#  'coffee': 1994,
#  'wif': 7915,
#  'fren': 3149,
#  'drove': 2613,
#  'shell': 6427,
#  'lift': 4360,
#  'chikku': 1888,
#  'favourite': 2949,
#  'uve': 7654,
#  'invited': 3929,
#  'xchat': 8113,
#  'final': 3004,
#  'attempt': 1196,
#  'finished': 3016,
#  'yet': 8172,
#  '07732584351': 24,
#  'rodger': 6160,
#  'burns': 1647,
#  'sms': 6626,
#  'camcorder': 1719,
#  '08000930705': 47,
#  'delivery': 2380,
#  'ger': 3277,
#  'toking': 7356,
#  'abt': 836,
#  'syd': 7056,
#  'lehhaha': 4320,
#  'mm': 4814,
#  'entirely': 2759,
#  'ho': 3649,
#  'liked': 4368,
#  'mnths': 4821,
#  'etc': 2790,
#  'double': 2565,
#  'mins': 4778,
#  'tariffs': 7103,
#  'callback': 1700,
#  'remove': 6041,
#  'records': 5981,
#  'antibiotic': 1066,
#  'chest': 1878,
#  'abdomen': 823,
#  'gynae': 3465,
#  'infections': 3869,
#  'even': 2804,
#  'bone': 1503,
#  'belive': 1385,
#  'tat': 7108,
#  'cd': 1795,
#  'forget': 3100,
#  'miiiiiiissssssssss': 4755,
#  'crave': 2180,
#  'sad': 6225,
#  'test': 7178,
#  'earlier': 2650,
#  'appreciate': 1102,
#  'sch': 6293,
#  'neva': 5034,
#  'mind': 4767,
#  'eat': 2666,
#  '1st': 375,
#  'bold': 1499,
#  'torch': 7398,
#  '2bold': 437,
#  'grand': 3394,
#  'party': 5428,
#  'doesnt': 2530,
#  'mention': 4714,
#  'charge': 1835,
#  'served': 6381,
#  'spoons': 6776,
#  'senthil': 6373,
#  'group': 3429,
#  'company': 2038,
#  'apnt': 1086,
#  '5pm': 628,
#  '09066350750': 224,
#  'tcs': 7122,
#  '434': 554,
#  'sk3': 6556,
#  '8wp': 794,
#  '150': 311,
#  'ppm': 5685,
#  'attend': 1198,
#  'lesson': 4333,
#  'mean': 4670,
#  'intrude': 3922,
#  'tuition': 7493,
#  'last': 4270,
#  'semester': 6356,
#  'lolnice': 4445,
#  'fish': 3028,
#  'dun': 2637,
#  'seeing': 6336,
#  'silver': 6519,
#  'black': 1450,
#  'pilates': 5546,
#  'yoga': 8180,
#  'transport': 7437,
#  'less': 4331,
#  'problematic': 5764,
#  'sat': 6263,
#  'join': 4055,
#  'bday': 1349,
#  'definite': 2364,
#  'nos': 5127,
#  'booking': 1511,
#  'ass': 1175,
#  'doggy': 2537,
#  'style': 6939,
#  'sunday': 6989,
#  'argh': 1126,
#  'nobody': 5093,
#  'town': 7415,
#  'masters': 4637,
#  'bb': 1332,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8240 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel()) # converting the labels as vetors - i.e the y_train

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))

# Precision -- 100% identified spam as spam
# Recall -- out of all the spam, 76% the model identified as spam
# Accuracy -- Spam or not prediction is correct for 96%
# Out:
# Precision: 1.0 / Recall: 0.767 / Accuracy: 0.969
