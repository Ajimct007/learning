# %% [markdown]
# # Supplemental Data Cleaning: Using a Lemmatizer

# %% [markdown]
# ### Test out WordNet lemmatizer (read more about WordNet [here](https://wordnet.princeton.edu/))

# %%
import nltk
nltk.download('wordnet')
wn = nltk.WordNetLemmatizer() # It has collection of words, nouns, verbs, Adjectives and Adverbs
# It grouped together in sort of synonyms, each expressing distinct concept

ps = nltk.PorterStemmer() # Here we are having stemmer to see the difference
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
dir(wn)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'lemmatize']

# %%
# Using the stemming
print(ps.stem('meanness'))
print(ps.stem('meaning'))
# Out:
# mean
# mean

# %%
# Let's see how the lemmantizer handles
print(wn.lemmatize('meanness'))
print(wn.lemmatize('meaning'))
# here it returned the same, since it does not contain
# Out:
# meanness
# meaning

# %%
# Lets check for related words
print(ps.stem('goose'))
print(ps.stem('geese'))
# Out:
# goos
# gees

# %%
print(wn.lemmatize('goose'))
print(wn.lemmatize('geese'))

# Here the Lemmantizer maps both of these correctly
# Out:
# goose
# goose

# %% [markdown]
# ### Read in raw text

# %%
import pandas as pd
import re
import string
pd.set_option('display.max_colwidth', 100)
nltk.download('stopwords')

stopwords = nltk.corpus.stopwords.words('english')

data = pd.read_csv("SMSSpamCollection.tsv", sep='\t')
data.columns = ['label', 'body_text']

data.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...

# %% [markdown]
# ### Clean up text

# %%
def clean_text(text):
    text = "".join([word for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [word for word in tokens if word not in stopwords]
    return text

data['body_text_nostop'] = data['body_text'].apply(lambda x: clean_text(x.lower()))

data.head()
# Out:
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...
#
#                                                                                       body_text_nostop
# 0  [free, entry, 2, wkly, comp, win, fa, cup, final, tkts, 21st, may, 2005, text, fa, 87121, receiv...
# ...

# %% [markdown]
# ### Lemmatize text

# %%
def lemmatizing(tokenized_text):
    text = [wn.lemmatize(word) for word in tokenized_text]
    return text

data['body_text_lemmatized'] = data['body_text_nostop'].apply(lambda x: lemmatizing(x))

data.head(10)
# Out:
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
# 5  spam
# 6  spam
# 7   ham
# 8  spam
# 9  spam
#
#                                                                                              body_text  \
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...
# 5  WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To c...
# 6  Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with came...
# ...
