# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\Data Science\\Code basics\\math-for-machine-learning-main\\1_log\\revenue.csv")
df.head(20)
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
df.plot(x='company',y='revenue',kind = 'bar')
# Out:
# <Axes: xlabel='company'>

# %%
#Since the amazon's bar is high the remaining are looks flat, so we have to use logarithm for better understanding

# %%
df.plot(x='company',y='revenue',kind = 'bar', log = True)
# Out:
# <Axes: xlabel='company'>

# %%
#another example
df2=pd.read_csv("D:\\Data Science\\Code basics\\math-for-machine-learning-main\\1_log\\income.csv")
df2.head()
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
