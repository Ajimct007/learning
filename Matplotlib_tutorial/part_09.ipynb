# %% [markdown]
# # Plotting Live Data

# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
x_vals = [0, 1, 2, 3, 4, 5]
y_vals = [0, 1, 3, 2, 3, 5]

# %%
# plotting simple

plt.plot(x_vals,y_vals)


plt.tight_layout()

# %%
# Importing the function anumation from the matplot lib
from matplotlib.animation import FuncAnimation

## we are emptying our list

x_vals = []
y_vals = []

# the count() counts one number at a time

index = count()

def animate(i):
    x_vals.append(next(index))
    # x value just appends the count up by 1
    y_vals.append(random.randint(0, 5))
    # y value will append random value between 0 and 5
    
    #for clear the axis
    plt.cla()
    
    ## plotting the values
    plt.plot(x_vals,y_vals)
    
    

# for running the function every second, we can use the func animations from matplot lib
    
## using the Funcanimation
ani = FuncAnimation(plt.gcf(), animate, interval=1000)
## gct -- get current figure
## animate for running the function
## interval for how often to run, we set it for 1000 means it take interval of 1 sec

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ajith\AppData\Local\Temp\ipykernel_7120\2790460241.py:30: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(plt.gcf(), animate, interval=1000)
# C:\Users\Ajith\anaconda3\lib\site-packages\matplotlib\animation.py:880: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %% [markdown]
# ## the live plotting of data not workin in the Jupyter notebook, so we are using it in a normal python file

# %% [markdown]
# ## we are going to use a csv file which is constantly updated by anothr python script

# %% [markdown]
# ## getting latest new data is not working properly showing errors so i skipped it
